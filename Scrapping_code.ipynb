# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin


def extract_links_with_keywords(base_url, keyword):
    response = requests.get(base_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        links = soup.find_all('a', href=True)
        filtered_links = [urljoin(base_url, link['href']) for link in links if keyword in link['href']]
        return filtered_links
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

def extract_table_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        # Using pandas read_html to directly get all tables in the page
        dataframes = pd.read_html(response.content)
        return dataframes
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

def get_table_links(base_url):
    response = requests.get(base_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        main_table = soup.find('table')
        rows = main_table.find_all('tr')

        link_data = []
        for row in rows:
            cells = row.find_all('td')
            row_data = [cell.text.strip() for cell in cells]
            link = row.find('a', href=True)
            if link:
                row_data.append(urljoin(base_url, link['href']))
            link_data.append(row_data)

        return link_data
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

def create_dataframes_from_rows(main_table_df, links_data):
    all_dataframes = []
    for i, row in main_table_df.iterrows():
        row_data = row.tolist()
        link = links_data[i][-1] if links_data[i] and len(links_data[i]) > len(row_data) else None
        if link:
            tables = extract_table_from_url(link)
            if tables:
                for table in tables:
                    # Create a new header that combines row data and the table headers
                    combined_headers = pd.MultiIndex.from_arrays([row_data + [""] * (len(table.columns) - len(row_data)), table.columns])
                    new_df = pd.DataFrame(table.values, columns=combined_headers)
                    all_dataframes.append(new_df)
    return all_dataframes

# %%
# THESE ARE THE PARTY WISE RESULTS OF LOK SABHA ELECTIONS 2024

base_url="https://results.eci.gov.in/PcResultGenJune2024/index.htm"

df=extract_table_from_url(base_url)



print(df)
# Out:
# [                                                Party  Won  Leading  Total
# 0                        Bharatiya Janata Party - BJP  240        0    240
# 1                      Indian National Congress - INC   99        0     99
# 2                                Samajwadi Party - SP   37        0     37
# 3                 All India Trinamool Congress - AITC   29        0     29
# 4                     Dravida Munnetra Kazhagam - DMK   22        0     22
# 5                                  Telugu Desam - TDP   16        0     16
# 6                         Janata Dal (United) - JD(U)   12        0     12
# 7      Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT    9        0      9
# 8   Nationalist Congress Party – Sharadchandra Paw...    8        0      8
# 9                                     Shiv Sena - SHS    7        0      7
# 10             Lok Janshakti Party(Ram Vilas) - LJPRV    5        0      5
# 11      Yuvajana Sramika Rythu Congress Party - YSRCP    4        0      4
# 12                         Rashtriya Janata Dal - RJD    4        0      4
# 13        Communist Party of India (Marxist) - CPI(M)    4        0      4
# 14                  Indian Union Muslim League - IUML    3        0      3
# 15                             Aam Aadmi Party - AAAP    3        0      3
# 16                       Jharkhand Mukti Morcha - JMM    3        0      3
# 17                               Janasena Party - JnP    2        0      2
# 18  Communist Party of India (Marxist-Leninist) (L...    2        0      2
# 19                       Janata Dal (Secular) - JD(S)    2        0      2
# 20               Viduthalai Chiruthaigal Katchi - VCK    2        0      2
# 21                     Communist Party of India - CPI    2        0      2
# 22                            Rashtriya Lok Dal - RLD    2        0      2
# 23          Jammu & Kashmir National Conference - JKN    2        0      2
# 24              United People’s Party, Liberal - UPPL    1        0      1
# 25                           Asom Gana Parishad - AGP    1        0      1
# 26            Hindustani Awam Morcha (Secular) - HAMS    1        0      1
# 27                              Kerala Congress - KEC    1        0      1
# 28                Revolutionary Socialist Party - RSP    1        0      1
# 29                   Nationalist Congress Party - NCP    1        0      1
# 30                  Voice of the People Party - VOTPP    1        0      1
# 31                      Zoram People’s Movement - ZPM    1        0      1
# 32                          Shiromani Akali Dal - SAD    1        0      1
# 33                  Rashtriya Loktantrik Party - RLTP    1        0      1
# 34                  Bharat Adivasi Party - BHRTADVSIP    1        0      1
# 35                     Sikkim Krantikari Morcha - SKM    1        0      1
# 36      Marumalarchi Dravida Munnetra Kazhagam - MDMK    1        0      1
# 37             Aazad Samaj Party (Kanshi Ram) - ASPKR    1        0      1
# 38                         Apna Dal (Soneylal) - ADAL    1        0      1
# 39                                 AJSU Party - AJSUP    1        0      1
# 40     All India Majlis-E-Ittehadul Muslimeen - AIMIM    1        0      1
# 41                                  Independent - IND    7        0      7
# 42                                              Total  543        0    543]

# %%
# THESE ARE THE CANDIDATE WISE RESULTS FROM EACH POLITICAL PARTY

base_url = "https://results.eci.gov.in/PcResultGenJune2024/index.htm"

# step 1: main DataFrame
main_dfs = extract_table_from_url(base_url)
main_df = main_dfs[0] if main_dfs else pd.DataFrame()

# step 2: getting all the links
links_data = get_table_links(base_url)

# step 3:creating new dataframes
all_dataframes = create_dataframes_from_rows(main_df, links_data)


for i, df1 in enumerate(all_dataframes):
    print(f"DataFrame {i + 1}:")
    print(df1.head())
# Out:
# DataFrame 1:
#   Indian National Congress - INC                      99  \
#                             S.No Parliament Constituency
# 0                              1           Anakapalle(5)
# 1                              2          Rajahmundry(8)
# 2                              3           Narsapuram(9)
# 3                              4       Arunachal West(1)
# 4                              5       Arunachal East(2)
#
#                                              0          99
#                              Winning Candidate Total Votes  Margin
# 0                                   C.M.RAMESH      762069  296530
# 1                     DAGGUBATI PURANDHESHWARI      726515  239139
# 2  BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)      707343  276802
# 3                                 KIREN RIJIJU      205417  100738
# 4                                    TAPIR GAO      145581   30421
# DataFrame 2:
#   Samajwadi Party - SP                      37                 0          37  \
#                   S.No Parliament Constituency Winning Candidate Total Votes
# 0                    1              Dhubri (2)   RAKIBUL HUSSAIN     1471885
# 1                    2               Nagaon(9)  PRADYUT BORDOLOI      788850
# 2                    3              Jorhat(14)      GAURAV GOGOI      751771
# 3                    4          Kishanganj(10)    MOHAMMAD JAWED      402850
# 4                    5             Katihar(11)       TARIQ ANWAR      567092
#
#
#     Margin
# 0  1012476
# 1   212231
# 2   144393
# 3    59692
# 4    49863
# DataFrame 3:
#   All India Trinamool Congress - AITC                      29  \
#                                  S.No Parliament Constituency
# 0                                   1              Kairana(2)
# 1                                   2        Muzaffarnagar(3)
# 2                                   3            Moradabad(6)
# 3                                   4               Rampur(7)
# 4                                   5              Sambhal(8)
#
#                       0          29
#       Winning Candidate Total Votes  Margin
# 0        IQRA CHOUDHARY      528013   69116
# 1  HARENDRA SINGH MALIK      470721   24672
# 2            RUCHI VIRA      637363  105762
# 3           MOHIBBULLAH      481503   87434
# 4         ZIA UR REHMAN      571161  121494
# DataFrame 4:
#   Dravida Munnetra Kazhagam - DMK                      22  \
#                              S.No Parliament Constituency
# 0                               1           Coochbehar(1)
# 1                               2             Jangipur(9)
# 2                               3          Baharampur(10)
# 3                               4         Murshidabad(11)
# 4                               5        Krishnanagar(12)
#
#                                 0          22
#                 Winning Candidate Total Votes  Margin
# 0  JAGADISH CHANDRA BARMA BASUNIA      788375   39250
# 1                KHALILUR RAHAMAN      544427  116637
# 2                    PATHAN YUSUF      524516   85022
# 3                  ABU TAHER KHAN      682442  164215
# 4                    MAHUA MOITRA      628789   56705
# DataFrame 5:
#   Telugu Desam - TDP                      16  \
#                 S.No Parliament Constituency
# 0                  1        CHENNAI NORTH(2)
# 1                  2        CHENNAI SOUTH(3)
# 2                  3      CHENNAI CENTRAL(4)
# 3                  4        SRIPERUMBUDUR(5)
# 4                  5         KANCHEEPURAM(6)
#
#                                              0          16
#                              Winning Candidate Total Votes  Margin
# 0                      DR.KALANIDHI VEERASWAMY      497333  339222
# 1  T.SUMATHY (ALIAS) THAMIZHACHI THANGAPANDIAN      516628  225945
# 2                              DAYANIDHI MARAN      413848  244689
# 3                                    T R BAALU      758611  487029
# 4                                    SELVAM. G      586044  221473
# DataFrame 6:
#   Janata Dal (United) - JD(U)                      12  \
#                          S.No Parliament Constituency
# 0                           1           Srikakulam(2)
# 1                           2         Vizianagaram(3)
# 2                           3        Visakhapatnam(4)
# 3                           4      Amalapuram (SC)(7)
# 4                           5               Eluru(10)
#
#                           0          12
#           Winning Candidate Total Votes  Margin
# 0  KINJARAPU RAMMOHAN NAIDU      754328  327901
# 1     APPALANAIDU KALISETTI      743113  249351
# 2     SRIBHARAT MATHUKUMILI      907467  504247
# 3     G M HARISH (BALAYOGI)      796981  342196
# 4        PUTTA MAHESH KUMAR      746351  181857
# DataFrame 7:
#   Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT                       9  \
#                                             S.No Parliament Constituency
# 0                                              1       Valmiki Nagar (1)
# 1                                              2              Sheohar(4)
# 2                                              3            Sitamarhi(5)
# 3                                              4          Jhanjharpur(7)
# 4                                              5               Supaul(8)
#
#                        0           9
#        Winning Candidate Total Votes  Margin
# 0            SUNIL KUMAR      523422   98675
# 1           LOVELY ANAND      476612   29143
# 2  DEVESH CHANDRA THAKUR      515719   51356
# 3         RAMPRIT MANDAL      533032  184169
# 4       DILESHWAR KAMAIT      595038  169803
# DataFrame 8:
#   Nationalist Congress Party – Sharadchandra Pawar - NCPSP  \
#                                                       S.No
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  5
#
#                         8                                 0           8  \
#   Parliament Constituency                 Winning Candidate Total Votes
# 0    Yavatmal- Washim(14)          SANJAY UTTAMRAO DESHMUKH      594807
# 1             Hingoli(15)    AASHTIKAR PATIL NAGESH BAPURAO      492535
# 2            Parbhani(17)  JADHAV SANJAY ( BANDU ) HARIBHAU      601343
# 3              Nashik(21)     RAJABHAU (PARAG) PRAKASH WAJE      616729
# 4   Mumbai North East(28)                 SANJAY DINA PATIL      450937
#
#
#    Margin
# 0   94473
# 1  108602
# 2  134061
# 3  162001
# 4   29861
# DataFrame 9:
#   Shiv Sena - SHS                       7  \
#              S.No Parliament Constituency
# 0               1               Wardha(8)
# 1               2            Dindori (20)
# 2               3            Bhiwandi(23)
# 3               4            Baramati(35)
# 4               5              Shirur(36)
#
#                                      0           7
#                      Winning Candidate Total Votes  Margin
# 0                  AMAR SHARADRAO KALE      533106   81648
# 1            BHASKAR MURLIDHAR BHAGARE      577339  113199
# 2  BALYA MAMA - SURESH GOPINATH MHATRE      499464   66121
# 3                         SUPRIYA SULE      732312  158333
# 4               DR. AMOL RAMSING KOLHE      698692  140951
# DataFrame 10:
#   Lok Janshakti Party(Ram Vilas) - LJPRV                       5  \
#                                     S.No Parliament Constituency
# 0                                      1             Buldhana(5)
# 1                                      2          Aurangabad(19)
# 2                                      3              Kalyan(24)
# 3                                      4               Thane(25)
# 4                                      5   Mumbai North West(27)
#
#                             0           5
#             Winning Candidate Total Votes  Margin
# 0  JADHAV PRATAPRAO GANPATRAO      349867   29479
# 1  BHUMARE SANDIPANRAO ASARAM      476130  134650
# 2   DR SHRIKANT EKNATH SHINDE      589636  209144
# 3        NARESH GANPAT MHASKE      734231  217011
# 4    RAVINDRA DATTARAM WAIKAR      452644      48
# DataFrame 11:
#   Yuvajana Sramika Rythu Congress Party - YSRCP                       4  \
#                                            S.No Parliament Constituency
# 0                                             1            Vaishali(16)
# 1                                             2             Hajipur(21)
# 2                                             3          Samastipur(23)
# 3                                             4            Khagaria(25)
# 4                                             5               Jamui(40)
#
#                   0           4
#   Winning Candidate Total Votes  Margin
# 0        VEENA DEVI      567043   89634
# 1     CHIRAG PASWAN      615718  170105
# 2         SHAMBHAVI      579786  187251
# 3      RAJESH VERMA      538657  161131
# 4       ARUN BHARTI      509046  112482
# DataFrame 12:
#   Rashtriya Janata Dal - RJD                       4                    0  \
#                         S.No Parliament Constituency    Winning Candidate
# 0                          1           Araku (ST)(1)   GUMMA THANUJA RANI
# 1                          2              Kadapa(21)  Y. S. AVINASH REDDY
# 2                          3      Thirupathi(SC)(23)  GURUMOORTHY MADDILA
# 3                          4            Rajampet(24)     P V MIDHUN REDDY
#
#             4
#   Total Votes Margin
# 0      477005  50580
# 1      605143  62695
# 2      632228  14569
# 3      644844  76071
# DataFrame 13:
#   Communist Party of India (Marxist) - CPI(M)                       4  \
#                                          S.No Parliament Constituency
# 0                                           1          Patliputra(31)
# 1                                           2               Buxar(33)
# 2                                           3           Jahanabad(36)
# 3                                           4          Aurangabad(37)
#
#                        0           4
#        Winning Candidate Total Votes  Margin
# 0           MISHA BHARTI      613283   85174
# 1         SUDHAKAR SINGH      438345   30091
# 2  SURENDRA PRASAD YADAV      443035  142591
# 3      ABHAY KUMAR SINHA      465567   79111
# DataFrame 14:
#   Indian Union Muslim League - IUML                       3  \
#                                S.No Parliament Constituency
# 0                                 1             Alathur (9)
# 1                                 2                SIKAR(5)
# 2                                 3            DINDIGUL(22)
# 3                                 4             MADURAI(32)
#
#                    0           3
#    Winning Candidate Total Votes  Margin
# 0    K.RADHAKRISHNAN      403447   20111
# 1            AMRARAM      659300   72896
# 2  SACHITHANANTHAM R      670149  443821
# 3       VENKATESAN S      430323  209409
# DataFrame 15:
#   Aam Aadmi Party - AAAP                       3                            0  \
#                     S.No Parliament Constituency            Winning Candidate
# 0                      1           Malappuram(6)        E.T. MOHAMMED BASHEER
# 1                      2              Ponnani(7)  DR. M.P ABDUSSAMAD SAMADANI
# 2                      3      RAMANATHAPURAM(35)                  NAVASKANI K
#
#             3
#   Total Votes  Margin
# 0      644006  300118
# 1      562516  235760
# 2      509664  166782
# DataFrame 16:
#   Jharkhand Mukti Morcha - JMM                       3  \
#                           S.No Parliament Constituency
# 0                            1           Hoshiarpur(5)
# 1                            2       Anandpur Sahib(6)
# 2                            3             Sangrur(12)
#
#                           0           3
#           Winning Candidate Total Votes  Margin
# 0   DR. RAJ KUMAR CHABBEWAL      303859   44111
# 1      MALVINDER SINGH KANG      313217   10846
# 2  GURMEET SINGH MEET HAYER      364085  172560
# DataFrame 17:
#   Janasena Party - JnP                       2                    0  \
#                   S.No Parliament Constituency    Winning Candidate
# 0                    1             Rajmahal(1)  VIJAY KUMAR HANSDAK
# 1                    2                Dumka(2)          NALIN SOREN
# 2                    3           Singhbhum(10)           JOBA MAJHI
#
#             2
#   Total Votes  Margin
# 0      613371  178264
# 1      547370   22527
# 2      520164  168402
# DataFrame 18:
#   Communist Party of India (Marxist-Leninist) (Liberation) - CPI(ML)(L)  \
#                                                                    S.No
# 0                                                  1
# 1                                                  2
#
#                         2                                       0           2  \
#   Parliament Constituency                       Winning Candidate Total Votes
# 0             Kakinada(6)  TANGELLA UDAY SRINIVAS (TEA TIME UDAY)      729699
# 1       Machilipatnam(11)                 BALASHOWRY VALLABHANENI      724439
#
#
#    Margin
# 0  229491
# 1  223179
# DataFrame 19:
#   Janata Dal (Secular) - JD(S)                       2                 0  \
#                           S.No Parliament Constituency Winning Candidate
# 0                            1               Arrah(32)     SUDAMA PRASAD
# 1                            2             Karakat(35)    RAJA RAM SINGH
#
#             2
#   Total Votes  Margin
# 0      529382   59808
# 1      380581  105858
# DataFrame 20:
#   Viduthalai Chiruthaigal Katchi - VCK                       2  \
#                                   S.No Parliament Constituency
# 0                                    1              Mandya(20)
# 1                                    2               Kolar(28)
#
#                   0           2
#   Winning Candidate Total Votes  Margin
# 0  H.D. KUMARASWAMY      851881  284620
# 1   M. MALLESH BABU      691481   71388
# DataFrame 21:
#   Communist Party of India - CPI                       2  \
#                             S.No Parliament Constituency
# 0                              1          VILUPPURAM(13)
# 1                              2         CHIDAMBARAM(27)
#
#                       0           2
#       Winning Candidate Total Votes  Margin
# 0          RAVIKUMAR. D      477033   70703
# 1  THIRUMAAVALAVAN THOL      505084  103554
# DataFrame 22:
#   Rashtriya Lok Dal - RLD                       2                 0  \
#                      S.No Parliament Constituency Winning Candidate
# 0                       1            TIRUPPUR(18)    SUBBARAYAN, K.
# 1                       2        NAGAPATTINAM(29)        SELVARAJ V
#
#             2
#   Total Votes  Margin
# 0      472739  125928
# 1      465044  208957
# DataFrame 23:
#   Jammu & Kashmir National Conference - JKN                       2  \
#                                        S.No Parliament Constituency
# 0                                         1               Bijnor(4)
# 1                                         2             Baghpat(11)
#
#                      0           2
#      Winning Candidate Total Votes  Margin
# 0      CHANDAN CHAUHAN      404493   37508
# 1  DR RAJKUMAR SANGWAN      488967  159459
# DataFrame 24:
#   United People’s Party, Liberal - UPPL                       1  \
#                                    S.No Parliament Constituency
# 0                                     1             SRINAGAR(2)
# 1                                     2     ANANTNAG-RAJOURI(3)
#
#                          0           1
#          Winning Candidate Total Votes  Margin
# 0  AGA SYED RUHULLAH MEHDI      356866  188416
# 1         MIAN ALTAF AHMAD      521836  281794
# DataFrame 25:
#   Asom Gana Parishad - AGP                       1                   0  \
#                       S.No Parliament Constituency   Winning Candidate
# 0                        1           Kokrajhar (1)  JOYANTA BASUMATARY
#
#             1
#   Total Votes Margin
# 0      488995  51583
# DataFrame 26:
#   Hindustani Awam Morcha (Secular) - HAMS                       1  \
#                                      S.No Parliament Constituency
# 0                                       1              Barpeta(3)
#
#                         0           1
#         Winning Candidate Total Votes  Margin
# 0  PHANI BHUSAN CHOUDHURY      860113  222351
# DataFrame 27:
#   Kerala Congress - KEC                       1                 0           1  \
#                    S.No Parliament Constituency Winning Candidate Total Votes
# 0                     1                Gaya(38)  JITAN RAM MANJHI      494960
#
#
#    Margin
# 0  101812
# DataFrame 28:
#   Revolutionary Socialist Party - RSP                       1  \
#                                  S.No Parliament Constituency
# 0                                   1            Kottayam(14)
#
#                       0           1
#       Winning Candidate Total Votes Margin
# 0  ADV K FRANCIS GEORGE      364631  87266
# DataFrame 29:
#   Nationalist Congress Party - NCP                       1                  0  \
#                               S.No Parliament Constituency  Winning Candidate
# 0                                1              Kollam(18)  N K PREMACHANDRAN
#
#             1
#   Total Votes  Margin
# 0      443628  150302
# DataFrame 30:
#   Voice of the People Party - VOTPP                       1  \
#                                S.No Parliament Constituency
# 0                                 1              Raigad(32)
#
#                          0           1
#          Winning Candidate Total Votes Margin
# 0  TATKARE SUNIL DATTATREY      508352  82784
# DataFrame 31:
#   Zoram People’s Movement - ZPM                       1  \
#                            S.No Parliament Constituency
# 0                             1             Shillong(1)
#
#                              0           1
#              Winning Candidate Total Votes  Margin
# 0  DR. RICKY ANDREW J. SYNGKON      571078  371910
# DataFrame 32:
#   Shiromani Akali Dal - SAD                       1                        0  \
#                        S.No Parliament Constituency        Winning Candidate
# 0                         1              MIZORAM(1)  RICHARD VANLALHMANGAIHA
#
#             1
#   Total Votes Margin
# 0      208552  68288
# DataFrame 33:
#   Rashtriya Loktantrik Party - RLTP                       1  \
#                                S.No Parliament Constituency
# 0                                 1            Bathinda(11)
#
#                       0           1
#       Winning Candidate Total Votes Margin
# 0  HARSIMRAT KAUR BADAL      376558  49656
# DataFrame 34:
#   Bharat Adivasi Party - BHRTADVSIP                       1                 0  \
#                                S.No Parliament Constituency Winning Candidate
# 0                                 1              NAGAUR(14)   HANUMAN BENIWAL
#
#             1
#   Total Votes Margin
# 0      596955  42225
# DataFrame 35:
#   Sikkim Krantikari Morcha - SKM                       1                 0  \
#                             S.No Parliament Constituency Winning Candidate
# 0                              1           BANSWARA (20)    RAJ KUMAR ROAT
#
#             1
#   Total Votes  Margin
# 0      820831  247054
# DataFrame 36:
#   Marumalarchi Dravida Munnetra Kazhagam - MDMK                       1  \
#                                            S.No Parliament Constituency
# 0                                             1               Sikkim(1)
#
#                   0           1
#   Winning Candidate Total Votes Margin
# 0  INDRA HANG SUBBA      164396  80830
# DataFrame 37:
#   Aazad Samaj Party (Kanshi Ram) - ASPKR                       1  \
#                                     S.No Parliament Constituency
# 0                                      1     TIRUCHIRAPPALLI(24)
#
#                   0           1
#   Winning Candidate Total Votes  Margin
# 0       DURAI VAIKO      542213  313094
# DataFrame 38:
#   Apna Dal (Soneylal) - ADAL                       1                 0  \
#                         S.No Parliament Constituency Winning Candidate
# 0                          1               Nagina(5)    CHANDRASHEKHAR
#
#             1
#   Total Votes  Margin
# 0      512552  151473
# DataFrame 39:
#   AJSU Party - AJSUP                       1                 0           1  \
#                 S.No Parliament Constituency Winning Candidate Total Votes
# 0                  1            Mirzapur(79)    ANUPRIYA PATEL      471631
#
#
#   Margin
# 0  37810
# DataFrame 40:
#   All India Majlis-E-Ittehadul Muslimeen - AIMIM                       1  \
#                                             S.No Parliament Constituency
# 0                                              1              Giridih(6)
#
#                            0           1
#            Winning Candidate Total Votes Margin
# 0  CHANDRA PRAKASH CHOUDHARY      451139  80880
# DataFrame 41:
#   Independent - IND                       7                 0           7  \
#                S.No Parliament Constituency Winning Candidate Total Votes
# 0                 1            Hyderabad(9)  ASADUDDIN OWAISI      661981
#
#
#    Margin
# 0  338087
# DataFrame 42:
#   Total                     543                                0         543  \
#    S.No Parliament Constituency                Winning Candidate Total Votes
# 0     1              Purnia(12)  RAJESH RANJAN ALIAS PAPPU YADAV      567556
# 1     2              Sangli(44)  VISHAL (DADA) PRAKASHBAPU PATIL      571666
# 2     3        Khadoor Sahib(3)                   AMRITPAL SINGH      404430
# 3     4             Faridkot(9)           SARABJEET SINGH KHALSA      298062
# 4     5         Daman & Diu (1)         PATEL UMESHBHAI BABUBHAI       42523
#
#
#    Margin
# 0   23847
# 1  100053
# 2  197120
# 3   70053
# 4    6225
